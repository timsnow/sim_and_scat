# %% [markdown]
# <div class="w3-bar w3-padding" style="background-color:#50565E">
#     <div class="w3-bar-item">
#         <a href='http://pythoninchemistry.org'>
#             <img class="w3-image" style="width:5%" src="../images/python_in_chemistry.png">
#         </a>
#     </div>
#     <div class="w3-bar-item">
#         <h1 style='color:#FFFFFF;
#                    font-size:1vw;
#                    font-weight:700;
#                    font-family:-apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, Oxygen, Ubuntu, Cantarell, "Open Sans", "Helvetica Neue", sans-serif;
#                    margin:10px 0 25px 0'>
#             pythoninchemistry
#         </h1>
#     </div>
#     <br>
#     <div class="w3-bar-item">
#         <h2 style='color:#FFFFFF;
#                    font-size:1.5vw;
#                    font-weight:300;
#                    font-family:-apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, Oxygen, Ubuntu, Cantarell, "Open Sans", "Helvetica Neue", sans-serif;'>
#             <a href="./00_schedule.html">
#                 The interaction between simulation and scattering
#             </a>
#         </h2>
#     </div>
# </div>
